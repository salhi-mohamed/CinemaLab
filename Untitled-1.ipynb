# %% [markdown]
# ## Data loading

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv('data.csv')

# %% [markdown]
# ## Checking for missing data

# %%
# les dimensions du dataset
print(f"Dimensions du dataset : {df.shape}")

# Vérifier si le nombre de lignes est ≤ 500
if df.shape[0] <= 500:
    print("Le dataset a 500 lignes ou moins.")
else:
    print("Le dataset a plus de 500 lignes.")

# Vérifier les données manquantes pour chaque feature
missing_data = df.isnull().sum()
print("\nDonnées manquantes par feature :")
print(missing_data[missing_data > 0])  
# Pourcentage de données manquantes par feature
if missing_data.sum() > 0:
    print("\nPourcentage de données manquantes par feature :")
    print((df.isnull().mean() * 100).round(2)[missing_data > 0])
else:
    print("\nAucune donnée manquante dans le dataset.")
# Out:
# Dimensions du dataset : (4380, 14)
# Le dataset a plus de 500 lignes.
#
# Données manquantes par feature :
# Series([], dtype: int64)
#
# Aucune donnée manquante dans le dataset.

# %% [markdown]
# ## Handling missing data (Dropping)

# %%
import pandas as pd
import numpy as np

# Chargement du fichier CSV, en considérant '-' comme valeur manquante
df = pd.read_csv('data.csv', na_values='-')

# Suppression des lignes contenant au moins une valeur manquante
df_clean = df.dropna()

# Vérification
print(f"Dimensions originales : {df.shape}")
print(f"Dimensions après suppression des lignes incomplètes : {df_clean.shape}")
# Out:
# Dimensions originales : (4380, 14)
# Dimensions après suppression des lignes incomplètes : (4047, 14)

# %% [markdown]
# ## Describtive statistics

# %%
quantitative_vars = [
    'runtime_minutes', 'Production budget $', 'Domestic gross $', 
    'Worldwide gross $', 'movie_averageRating', 'movie_numerOfVotes','approval_Index'
]

# Statistiques descriptives
print("Statistiques descriptives :\n", df_clean[quantitative_vars].describe().round(2))


df_clean.describe()
# Out:
# Statistiques descriptives :
#         runtime_minutes  Production budget $  Domestic gross $  \
# count          4047.00         4.047000e+03      4.047000e+03
# mean            110.45         3.772737e+07      5.005642e+07
# std              20.11         4.455328e+07      7.094637e+07
# min              65.00         5.000000e+04      2.640000e+02
# 25%              96.00         1.000000e+07      8.326902e+06
# 50%             107.00         2.270000e+07      2.728887e+07
# 75%             120.00         5.000000e+07      6.167317e+07
# max             271.00         4.600000e+08      8.141151e+08
#
#        Worldwide gross $  movie_averageRating  movie_numerOfVotes  \
# count       4.047000e+03              4047.00             4047.00
# mean        1.079035e+08                 6.40           134370.02
# std         1.865220e+08                 1.02           212703.41
# min         4.230000e+02                 1.50                5.00
# 25%         1.279661e+07                 5.80            21404.00
# 50%         4.248816e+07                 6.50            63990.00
# 75%         1.213727e+08                 7.10           155694.00
# max         2.923706e+09                 9.30          2695887.00
#
#        approval_Index
# count         4047.00
# mean             5.03
# std              1.36
# min              0.45
# 25%              4.18
# 50%              5.02
# 75%              5.92
# max             10.00
#        runtime_minutes  movie_averageRating  movie_numerOfVotes  \
# count      4047.000000          4047.000000        4.047000e+03
# mean        110.454411             6.400890        1.343700e+05
# std          20.113355             1.015928        2.127034e+05
# min          65.000000             1.500000        5.000000e+00
# 25%          96.000000             5.800000        2.140400e+04
# 50%         107.000000             6.500000        6.399000e+04
# 75%         120.000000             7.100000        1.556940e+05
# max         271.000000             9.300000        2.695887e+06
#
#        approval_Index  Production budget $  Domestic gross $  \
# count     4047.000000         4.047000e+03      4.047000e+03
# mean         5.027986         3.772737e+07      5.005642e+07
# std          1.362437         4.455328e+07      7.094637e+07
# min          0.449597         5.000000e+04      2.640000e+02
# 25%          4.183751         1.000000e+07      8.326902e+06
# 50%          5.024142         2.270000e+07      2.728887e+07
# 75%          5.922643         5.000000e+07      6.167317e+07
# max         10.000000         4.600000e+08      8.141151e+08
#
#        Worldwide gross $
# count       4.047000e+03
# mean        1.079035e+08
# std         1.865220e+08
# min         4.230000e+02
# 25%         1.279661e+07
# 50%         4.248816e+07
# 75%         1.213727e+08
# max         2.923706e+09

# %% [markdown]
# ## Distributions

# %%
from scipy.stats import skew, kurtosis

for var in quantitative_vars:
    print(f"\n--- Distribution de la variable : {var} ---")
    serie = df_clean[var].dropna()
    
    print(f"Nombre de valeurs : {serie.count()}")
    print(f"Valeur minimale : {serie.min()}")
    print(f"1er quartile (Q1) : {serie.quantile(0.25)}")
    print(f"Médiane (Q2) : {serie.median()}")
    print(f"3e quartile (Q3) : {serie.quantile(0.75)}")
    print(f"Valeur maximale : {serie.max()}")
    print(f"Moyenne : {serie.mean():.2f}")
    print(f"Écart-type : {serie.std():.2f}")
    print(f"Asymétrie (Skewness) : {skew(serie):.2f}")
    print(f"Aplatissement (Kurtosis) : {kurtosis(serie):.2f}")
    
    iqr = serie.quantile(0.75) - serie.quantile(0.25)
    lower_bound = serie.quantile(0.25) - 1.5 * iqr
    upper_bound = serie.quantile(0.75) + 1.5 * iqr
    outliers = serie[(serie < lower_bound) | (serie > upper_bound)]
    
    outliers_low = serie[serie < lower_bound]
    outliers_high = serie[serie > upper_bound]

    print(f"Nombre de valeurs aberrantes (outliers) : {len(outliers)}")
    print(f" → En dessous du lower bound : {len(outliers_low)}")
    print(f" → Au-dessus du upper bound : {len(outliers_high)}")
    print(f"lower bound  : {lower_bound:.2f}")
    print(f"upper bound  : {upper_bound:.2f}")
# Out:
# --- Distribution de la variable : runtime_minutes ---
# Nombre de valeurs : 4047
# Valeur minimale : 65.0
# 1er quartile (Q1) : 96.0
# Médiane (Q2) : 107.0
# 3e quartile (Q3) : 120.0
# Valeur maximale : 271.0
# Moyenne : 110.45
# Écart-type : 20.11
# Asymétrie (Skewness) : 1.50
# Aplatissement (Kurtosis) : 4.42
# Nombre de valeurs aberrantes (outliers) : 124
#  → En dessous du lower bound : 0
#  → Au-dessus du upper bound : 124
# lower bound  : 60.00
# upper bound  : 156.00
#
# --- Distribution de la variable : Production budget $ ---
# Nombre de valeurs : 4047
# Valeur minimale : 50000
# 1er quartile (Q1) : 10000000.0
# Médiane (Q2) : 22700000.0
# 3e quartile (Q3) : 50000000.0
# Valeur maximale : 460000000
# Moyenne : 37727367.48
# Écart-type : 44553279.12
# Asymétrie (Skewness) : 2.48
# Aplatissement (Kurtosis) : 8.38
# Nombre de valeurs aberrantes (outliers) : 270
#  → En dessous du lower bound : 0
#  → Au-dessus du upper bound : 270
# lower bound  : -50000000.00
# upper bound  : 110000000.00
#
# --- Distribution de la variable : Domestic gross $ ---
# Nombre de valeurs : 4047
# Valeur minimale : 264
# 1er quartile (Q1) : 8326902.5
# Médiane (Q2) : 27288872.0
# 3e quartile (Q3) : 61673173.5
# Valeur maximale : 814115070
# Moyenne : 50056416.28
# Écart-type : 70946369.46
# Asymétrie (Skewness) : 3.75
# Aplatissement (Kurtosis) : 22.11
# Nombre de valeurs aberrantes (outliers) : 315
#  → En dessous du lower bound : 0
#  → Au-dessus du upper bound : 315
# lower bound  : -71692504.00
# upper bound  : 141692580.00
#
# --- Distribution de la variable : Worldwide gross $ ---
# Nombre de valeurs : 4047
# Valeur minimale : 423
# 1er quartile (Q1) : 12796606.5
# Médiane (Q2) : 42488161.0
# 3e quartile (Q3) : 121372695.0
# Valeur maximale : 2923706026
# Moyenne : 107903473.98
# Écart-type : 186522028.39
# Asymétrie (Skewness) : 4.64
# Aplatissement (Kurtosis) : 35.21
# Nombre de valeurs aberrantes (outliers) : 392
#  → En dessous du lower bound : 0
#  → Au-dessus du upper bound : 392
# lower bound  : -150067526.25
# upper bound  : 284236827.75
#
# --- Distribution de la variable : movie_averageRating ---
# Nombre de valeurs : 4047
# Valeur minimale : 1.5
# 1er quartile (Q1) : 5.8
# Médiane (Q2) : 6.5
# 3e quartile (Q3) : 7.1
# Valeur maximale : 9.3
# Moyenne : 6.40
# Écart-type : 1.02
# Asymétrie (Skewness) : -0.63
# Aplatissement (Kurtosis) : 1.05
# Nombre de valeurs aberrantes (outliers) : 73
#  → En dessous du lower bound : 71
#  → Au-dessus du upper bound : 2
# lower bound  : 3.85
# upper bound  : 9.05
#
# --- Distribution de la variable : movie_numerOfVotes ---
# Nombre de valeurs : 4047
# Valeur minimale : 5.0
# 1er quartile (Q1) : 21404.0
# Médiane (Q2) : 63990.0
# 3e quartile (Q3) : 155694.0
# Valeur maximale : 2695887.0
# Moyenne : 134370.02
# Écart-type : 212703.41
# Asymétrie (Skewness) : 4.47
# Aplatissement (Kurtosis) : 30.72
# Nombre de valeurs aberrantes (outliers) : 353
#  → En dessous du lower bound : 0
#  → Au-dessus du upper bound : 353
# lower bound  : -180031.00
# upper bound  : 357129.00
#
# --- Distribution de la variable : approval_Index ---
# Nombre de valeurs : 4047
# Valeur minimale : 0.4495974051314765
# 1er quartile (Q1) : 4.1837505276568425
# Médiane (Q2) : 5.024142381948415
# 3e quartile (Q3) : 5.922643040360067
# Valeur maximale : 10.0
# Moyenne : 5.03
# Écart-type : 1.36
# Asymétrie (Skewness) : -0.04
# Aplatissement (Kurtosis) : 0.29
# Nombre de valeurs aberrantes (outliers) : 69
#  → En dessous du lower bound : 41
#  → Au-dessus du upper bound : 28
# lower bound  : 1.58
# upper bound  : 8.53

# %% [markdown]
# ## Boxplots

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Boxplot vertical pour 'runtime_minutes'
plt.figure(figsize=(5, 10))
sns.boxplot(y=df_clean['runtime_minutes'], color='skyblue')
plt.title('Boxplot de la durée des films (en minutes)')
plt.ylabel('Durée (minutes)')
plt.grid(True, axis='y')
plt.show()

# %%
# Boxplot pour movie_averageRating
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(5, 10))
sns.boxplot(y=df_clean['movie_averageRating'], color='skyblue')
plt.title('Boxplot de la note moyenne des films')
plt.ylabel('note moyenne')
plt.grid(True, axis='y')
plt.show()

# %%
# Distribution des variables quantitatives
for var in quantitative_vars:
    plt.figure(figsize=(8, 4))
    sns.histplot(df[var], kde=True, bins=30)
    plt.title(f'Distribution de {var}')
    plt.show()

# %% [markdown]
# ## Comparative study based on genre

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Copie du DataFrame initial
df_genres = df_clean.copy()

# Extraction du premier genre uniquement
df_genres['genres'] = df_genres['genres'].str.split(',').str[0]

# Liste des colonnes quantitatives
quantitative_cols = df_genres.select_dtypes(include=['float64', 'int64']).columns.tolist()

# Moyenne des variables quantitatives par genre
genre_means = df_genres.groupby('genres')[quantitative_cols].mean().sort_index()

# ➤ Moyenne des moyennes par variable (moyenne globale des genres pour chaque variable)
mean_of_means = genre_means.mean()

genre_means.loc['Moyenne globale'] = mean_of_means

# Affichage de la heatmap avec la ligne "Moyenne globale"
plt.figure(figsize=(14, 8))
sns.heatmap(genre_means, annot=True, fmt=".1f", cmap="YlGnBu", linewidths=0.5)
plt.title("Moyenne des variables quantitatives par genre (incluant la moyenne globale)")
plt.xlabel("Variables quantitatives")
plt.ylabel("Genre")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df_genres = df_clean.copy()

df_genres['genres'] = df_genres['genres'].str.split(',').str[0]

# Liste des colonnes quantitatives
quantitative_cols = df_genres.select_dtypes(include=['float64', 'int64']).columns.tolist()

# Calculer la moyenne par genre
genre_means = df_genres.groupby('genres')[quantitative_cols].mean().sort_index()

# Affichage des résultats sous forme de texte
for genre in genre_means.index:
    print(f"\nGenre : {genre}")
    for col in genre_means.columns:
        print(f"  Moyenne de {col} : {genre_means.loc[genre, col]:.2f}")
# Out:
# Genre : Action
#   Moyenne de runtime_minutes : 113.17
#   Moyenne de movie_averageRating : 6.28
#   Moyenne de movie_numerOfVotes : 192350.59
#   Moyenne de approval_Index : 5.24
#   Moyenne de Production budget $ : 66427469.81
#   Moyenne de Domestic gross $ : 76683991.75
#   Moyenne de Worldwide gross $ : 186149406.78
#
# Genre : Adventure
#   Moyenne de runtime_minutes : 108.32
#   Moyenne de movie_averageRating : 6.36
#   Moyenne de movie_numerOfVotes : 139541.18
#   Moyenne de approval_Index : 5.05
#   Moyenne de Production budget $ : 54997087.61
#   Moyenne de Domestic gross $ : 73077020.56
#   Moyenne de Worldwide gross $ : 175650132.30
#
# Genre : Animation
#   Moyenne de runtime_minutes : 87.36
#   Moyenne de movie_averageRating : 6.33
#   Moyenne de movie_numerOfVotes : 82646.82
#   Moyenne de approval_Index : 4.87
#   Moyenne de Production budget $ : 41318181.82
#   Moyenne de Domestic gross $ : 35702801.45
#   Moyenne de Worldwide gross $ : 73693904.73
#
# Genre : Biography
#   Moyenne de runtime_minutes : 123.46
#   Moyenne de movie_averageRating : 7.07
#   Moyenne de movie_numerOfVotes : 122758.43
#   Moyenne de approval_Index : 5.60
#   Moyenne de Production budget $ : 25216524.82
#   Moyenne de Domestic gross $ : 34244045.79
#   Moyenne de Worldwide gross $ : 61894390.26
#
# Genre : Comedy
#   Moyenne de runtime_minutes : 102.34
#   Moyenne de movie_averageRating : 6.16
#   Moyenne de movie_numerOfVotes : 83566.68
#   Moyenne de approval_Index : 4.67
#   Moyenne de Production budget $ : 22961075.05
#   Moyenne de Domestic gross $ : 38459729.75
#   Moyenne de Worldwide gross $ : 63871059.79
#
# Genre : Crime
#   Moyenne de runtime_minutes : 115.08
#   Moyenne de movie_averageRating : 6.73
#   Moyenne de movie_numerOfVotes : 168476.62
#   Moyenne de approval_Index : 5.39
#   Moyenne de Production budget $ : 26648740.31
#   Moyenne de Domestic gross $ : 33053269.03
#   Moyenne de Worldwide gross $ : 65331135.21
#
# Genre : Documentary
#   Moyenne de runtime_minutes : 103.79
#   Moyenne de movie_averageRating : 6.93
#   Moyenne de movie_numerOfVotes : 19206.41
#   Moyenne de approval_Index : 3.94
#   Moyenne de Production budget $ : 7991911.76
#   Moyenne de Domestic gross $ : 13758136.74
#   Moyenne de Worldwide gross $ : 31673155.68
#
# Genre : Drama
#   Moyenne de runtime_minutes : 116.18
#   Moyenne de movie_averageRating : 6.71
#   Moyenne de movie_numerOfVotes : 118401.17
#   Moyenne de approval_Index : 5.05
#   Moyenne de Production budget $ : 21447327.67
#   Moyenne de Domestic gross $ : 30966477.16
#   Moyenne de Worldwide gross $ : 59573737.68
#
# Genre : Family
#   Moyenne de runtime_minutes : 102.25
#   Moyenne de movie_averageRating : 6.15
#   Moyenne de movie_numerOfVotes : 59057.00
#   Moyenne de approval_Index : 3.90
#   Moyenne de Production budget $ : 15000000.00
#   Moyenne de Domestic gross $ : 4142165.00
#   Moyenne de Worldwide gross $ : 8647809.50
#
# Genre : Fantasy
#   Moyenne de runtime_minutes : 104.72
#   Moyenne de movie_averageRating : 6.36
#   Moyenne de movie_numerOfVotes : 142216.56
#   Moyenne de approval_Index : 4.74
#   Moyenne de Production budget $ : 47637360.00
#   Moyenne de Domestic gross $ : 73289452.52
#   Moyenne de Worldwide gross $ : 194911606.68
#
# Genre : Film-Noir
#   Moyenne de runtime_minutes : 101.50
#   Moyenne de movie_averageRating : 7.25
#   Moyenne de movie_numerOfVotes : 33946.00
#   Moyenne de approval_Index : 5.38
#   Moyenne de Production budget $ : 1375000.00
#   Moyenne de Domestic gross $ : 4750000.00
#   Moyenne de Worldwide gross $ : 4750000.00
#
# Genre : Horror
#   Moyenne de runtime_minutes : 97.47
#   Moyenne de movie_averageRating : 5.77
#   Moyenne de movie_numerOfVotes : 99975.48
#   Moyenne de approval_Index : 4.52
#   Moyenne de Production budget $ : 15451963.35
#   Moyenne de Domestic gross $ : 39050981.83
#   Moyenne de Worldwide gross $ : 75228871.60
#
# Genre : Music
#   Moyenne de runtime_minutes : 93.00
#   Moyenne de movie_averageRating : 7.10
#   Moyenne de movie_numerOfVotes : 17795.00
#   Moyenne de approval_Index : 4.98
#   Moyenne de Production budget $ : 18000000.00
#   Moyenne de Domestic gross $ : 3419967.00
#   Moyenne de Worldwide gross $ : 9082906.00
#
# Genre : Musical
#   Moyenne de runtime_minutes : 111.50
#   Moyenne de movie_averageRating : 4.45
#   Moyenne de movie_numerOfVotes : 1042.00
#   Moyenne de approval_Index : 2.16
#   Moyenne de Production budget $ : 5050000.00
#   Moyenne de Domestic gross $ : 2015903.00
#   Moyenne de Worldwide gross $ : 2015903.00
#
# Genre : Mystery
#   Moyenne de runtime_minutes : 114.25
#   Moyenne de movie_averageRating : 6.18
#   Moyenne de movie_numerOfVotes : 242774.08
#   Moyenne de approval_Index : 4.96
#   Moyenne de Production budget $ : 32693560.75
#   Moyenne de Domestic gross $ : 43168457.33
#   Moyenne de Worldwide gross $ : 117886044.25
#
# Genre : Romance
#   Moyenne de runtime_minutes : 106.00
#   Moyenne de movie_averageRating : 7.00
#   Moyenne de movie_numerOfVotes : 260441.00
#   Moyenne de approval_Index : 6.29
#   Moyenne de Production budget $ : 50200000.00
#   Moyenne de Domestic gross $ : 62495645.00
#   Moyenne de Worldwide gross $ : 126931325.00
#
# Genre : Sci-Fi
#   Moyenne de runtime_minutes : 104.25
#   Moyenne de movie_averageRating : 6.73
#   Moyenne de movie_numerOfVotes : 231588.75
#   Moyenne de approval_Index : 5.66
#   Moyenne de Production budget $ : 40500000.00
#   Moyenne de Domestic gross $ : 26733314.00
#   Moyenne de Worldwide gross $ : 59165905.25
#
# Genre : Thriller
#   Moyenne de runtime_minutes : 99.20
#   Moyenne de movie_averageRating : 6.66
#   Moyenne de movie_numerOfVotes : 46105.00
#   Moyenne de approval_Index : 4.10
#   Moyenne de Production budget $ : 10300000.00
#   Moyenne de Domestic gross $ : 30311124.40
#   Moyenne de Worldwide gross $ : 58486460.80
#
# Genre : Western
#   Moyenne de runtime_minutes : 113.00
#   Moyenne de movie_averageRating : 5.60
#   Moyenne de movie_numerOfVotes : 3216.00
#   Moyenne de approval_Index : 3.20
#   Moyenne de Production budget $ : 1455000.00
#   Moyenne de Domestic gross $ : 2620000.00
#   Moyenne de Worldwide gross $ : 2620000.00
#
# Genre : \N
#   Moyenne de runtime_minutes : 118.00
#   Moyenne de movie_averageRating : 5.30
#   Moyenne de movie_numerOfVotes : 53.00
#   Moyenne de approval_Index : 1.42
#   Moyenne de Production budget $ : 30000000.00
#   Moyenne de Domestic gross $ : 3517797.00
#   Moyenne de Worldwide gross $ : 6460758.00

# %% [markdown]
# ## Comparative study based on director profession

# %%
import pandas as pd

# Exploser la colonne 'director_professions' pour gérer les professions mixtes
df_clean['director_professions'] = df_clean['director_professions'].str.split(',')
df_clean_exploded = df_clean.explode('director_professions').dropna(subset=['director_professions'])

# Liste des colonnes quantitatives
quantitative_cols = df_clean.select_dtypes(include=['float64', 'int64']).columns.tolist()

director_professions_means = df_clean_exploded.groupby('director_professions')[quantitative_cols].mean().sort_index()

# Affichage des résultats sous forme de texte
for profession, row in director_professions_means.iterrows():
    print(f"Profession : {profession}")
    for col in quantitative_cols:
        print(f"  Moyenne de {col} : {row[col]:.2f}")
    print("\n")
# Out:
# Profession : actor
#   Moyenne de runtime_minutes : 110.98
#   Moyenne de movie_averageRating : 6.47
#   Moyenne de movie_numerOfVotes : 134462.30
#   Moyenne de approval_Index : 5.07
#   Moyenne de Production budget $ : 36872515.15
#   Moyenne de Domestic gross $ : 49329434.94
#   Moyenne de Worldwide gross $ : 101440084.97
#
#
# Profession : actress
#   Moyenne de runtime_minutes : 106.59
#   Moyenne de movie_averageRating : 6.20
#   Moyenne de movie_numerOfVotes : 61206.48
#   Moyenne de approval_Index : 4.61
#   Moyenne de Production budget $ : 19858860.76
#   Moyenne de Domestic gross $ : 32612178.62
#   Moyenne de Worldwide gross $ : 51843515.08
#
#
# Profession : animation_department
#   Moyenne de runtime_minutes : 95.32
#   Moyenne de movie_averageRating : 6.29
#   Moyenne de movie_numerOfVotes : 93861.38
#   Moyenne de approval_Index : 4.90
#   Moyenne de Production budget $ : 65860273.97
#   Moyenne de Domestic gross $ : 63879144.79
#   Moyenne de Worldwide gross $ : 157188974.30
#
#
# Profession : art_department
#   Moyenne de runtime_minutes : 99.19
#   Moyenne de movie_averageRating : 6.19
#   Moyenne de movie_numerOfVotes : 74247.53
#   Moyenne de approval_Index : 4.54
#   Moyenne de Production budget $ : 52430000.00
#   Moyenne de Domestic gross $ : 44043321.06
#   Moyenne de Worldwide gross $ : 130926595.55
#
#
# Profession : art_director
#   Moyenne de runtime_minutes : 105.71
#   Moyenne de movie_averageRating : 6.40
#   Moyenne de movie_numerOfVotes : 45074.57
#   Moyenne de approval_Index : 4.16
#   Moyenne de Production budget $ : 13772857.14
#   Moyenne de Domestic gross $ : 12424110.00
#   Moyenne de Worldwide gross $ : 27284618.71
#
#
# Profession : assistant_director
#   Moyenne de runtime_minutes : 106.69
#   Moyenne de movie_averageRating : 6.13
#   Moyenne de movie_numerOfVotes : 65348.33
#   Moyenne de approval_Index : 4.52
#   Moyenne de Production budget $ : 27119360.95
#   Moyenne de Domestic gross $ : 30301197.20
#   Moyenne de Worldwide gross $ : 66451869.60
#
#
# Profession : camera_department
#   Moyenne de runtime_minutes : 101.36
#   Moyenne de movie_averageRating : 5.85
#   Moyenne de movie_numerOfVotes : 74136.97
#   Moyenne de approval_Index : 4.29
#   Moyenne de Production budget $ : 34456865.67
#   Moyenne de Domestic gross $ : 34663219.61
#   Moyenne de Worldwide gross $ : 72219165.97
#
#
# Profession : casting_department
#   Moyenne de runtime_minutes : 110.00
#   Moyenne de movie_averageRating : 5.85
#   Moyenne de movie_numerOfVotes : 8556.50
#   Moyenne de approval_Index : 3.49
#   Moyenne de Production budget $ : 4350000.00
#   Moyenne de Domestic gross $ : 5181933.50
#   Moyenne de Worldwide gross $ : 5221041.50
#
#
# Profession : casting_director
#   Moyenne de runtime_minutes : 110.67
#   Moyenne de movie_averageRating : 5.83
#   Moyenne de movie_numerOfVotes : 7988.33
#   Moyenne de approval_Index : 3.40
#   Moyenne de Production budget $ : 4700000.00
#   Moyenne de Domestic gross $ : 2470709.00
#   Moyenne de Worldwide gross $ : 7236822.67
#
#
# Profession : cinematographer
#   Moyenne de runtime_minutes : 106.78
#   Moyenne de movie_averageRating : 6.16
#   Moyenne de movie_numerOfVotes : 89863.36
#   Moyenne de approval_Index : 4.49
#   Moyenne de Production budget $ : 31789207.69
#   Moyenne de Domestic gross $ : 36489950.45
#   Moyenne de Worldwide gross $ : 73020859.61
#
#
# Profession : composer
#   Moyenne de runtime_minutes : 101.88
#   Moyenne de movie_averageRating : 6.21
#   Moyenne de movie_numerOfVotes : 90567.12
#   Moyenne de approval_Index : 4.88
#   Moyenne de Production budget $ : 17635000.00
#   Moyenne de Domestic gross $ : 20968356.80
#   Moyenne de Worldwide gross $ : 37634592.76
#
#
# Profession : costume_designer
#   Moyenne de runtime_minutes : 107.50
#   Moyenne de movie_averageRating : 7.50
#   Moyenne de movie_numerOfVotes : 199038.00
#   Moyenne de approval_Index : 6.55
#   Moyenne de Production budget $ : 14750000.00
#   Moyenne de Domestic gross $ : 9919678.50
#   Moyenne de Worldwide gross $ : 30270530.00
#
#
# Profession : director
#   Moyenne de runtime_minutes : 110.90
#   Moyenne de movie_averageRating : 6.41
#   Moyenne de movie_numerOfVotes : 135128.03
#   Moyenne de approval_Index : 5.03
#   Moyenne de Production budget $ : 37830297.89
#   Moyenne de Domestic gross $ : 50359751.10
#   Moyenne de Worldwide gross $ : 109183770.57
#
#
# Profession : editor
#   Moyenne de runtime_minutes : 108.73
#   Moyenne de movie_averageRating : 6.32
#   Moyenne de movie_numerOfVotes : 97971.85
#   Moyenne de approval_Index : 4.65
#   Moyenne de Production budget $ : 27095789.94
#   Moyenne de Domestic gross $ : 36349396.41
#   Moyenne de Worldwide gross $ : 84712872.23
#
#
# Profession : editorial_department
#   Moyenne de runtime_minutes : 105.28
#   Moyenne de movie_averageRating : 5.74
#   Moyenne de movie_numerOfVotes : 68555.43
#   Moyenne de approval_Index : 4.29
#   Moyenne de Production budget $ : 33480625.00
#   Moyenne de Domestic gross $ : 44324198.33
#   Moyenne de Worldwide gross $ : 99471180.45
#
#
# Profession : executive
#   Moyenne de runtime_minutes : 96.33
#   Moyenne de movie_averageRating : 5.52
#   Moyenne de movie_numerOfVotes : 64965.67
#   Moyenne de approval_Index : 4.28
#   Moyenne de Production budget $ : 51000000.00
#   Moyenne de Domestic gross $ : 42589165.33
#   Moyenne de Worldwide gross $ : 69726668.67
#
#
# Profession : location_management
#   Moyenne de runtime_minutes : 95.00
#   Moyenne de movie_averageRating : 5.90
#   Moyenne de movie_numerOfVotes : 32672.00
#   Moyenne de approval_Index : 4.38
#   Moyenne de Production budget $ : 8000000.00
#   Moyenne de Domestic gross $ : 109045.00
#   Moyenne de Worldwide gross $ : 3270974.00
#
#
# Profession : make_up_department
#   Moyenne de runtime_minutes : 105.33
#   Moyenne de movie_averageRating : 6.13
#   Moyenne de movie_numerOfVotes : 97176.33
#   Moyenne de approval_Index : 4.84
#   Moyenne de Production budget $ : 25041666.67
#   Moyenne de Domestic gross $ : 31327417.50
#   Moyenne de Worldwide gross $ : 60818617.67
#
#
# Profession : miscellaneous
#   Moyenne de runtime_minutes : 107.55
#   Moyenne de movie_averageRating : 6.27
#   Moyenne de movie_numerOfVotes : 113516.34
#   Moyenne de approval_Index : 4.91
#   Moyenne de Production budget $ : 42223136.65
#   Moyenne de Domestic gross $ : 54764808.22
#   Moyenne de Worldwide gross $ : 116014501.87
#
#
# Profession : music_artist
#   Moyenne de runtime_minutes : 123.75
#   Moyenne de movie_averageRating : 6.45
#   Moyenne de movie_numerOfVotes : 15172.00
#   Moyenne de approval_Index : 4.41
#   Moyenne de Production budget $ : 22250000.00
#   Moyenne de Domestic gross $ : 44528812.00
#   Moyenne de Worldwide gross $ : 44528812.00
#
#
# Profession : music_department
#   Moyenne de runtime_minutes : 106.23
#   Moyenne de movie_averageRating : 6.42
#   Moyenne de movie_numerOfVotes : 167326.11
#   Moyenne de approval_Index : 5.11
#   Moyenne de Production budget $ : 53694285.71
#   Moyenne de Domestic gross $ : 73396559.77
#   Moyenne de Worldwide gross $ : 145599672.60
#
#
# Profession : producer
#   Moyenne de runtime_minutes : 111.79
#   Moyenne de movie_averageRating : 6.43
#   Moyenne de movie_numerOfVotes : 149274.34
#   Moyenne de approval_Index : 5.12
#   Moyenne de Production budget $ : 40240149.04
#   Moyenne de Domestic gross $ : 54753755.92
#   Moyenne de Worldwide gross $ : 118106989.16
#
#
# Profession : production_designer
#   Moyenne de runtime_minutes : 118.86
#   Moyenne de movie_averageRating : 6.43
#   Moyenne de movie_numerOfVotes : 248378.72
#   Moyenne de approval_Index : 5.38
#   Moyenne de Production budget $ : 53805833.33
#   Moyenne de Domestic gross $ : 56905707.69
#   Moyenne de Worldwide gross $ : 141815035.44
#
#
# Profession : production_manager
#   Moyenne de runtime_minutes : 95.33
#   Moyenne de movie_averageRating : 5.62
#   Moyenne de movie_numerOfVotes : 33871.33
#   Moyenne de approval_Index : 4.00
#   Moyenne de Production budget $ : 21666666.67
#   Moyenne de Domestic gross $ : 16984977.33
#   Moyenne de Worldwide gross $ : 28901344.50
#
#
# Profession : script_department
#   Moyenne de runtime_minutes : 120.82
#   Moyenne de movie_averageRating : 6.66
#   Moyenne de movie_numerOfVotes : 79333.76
#   Moyenne de approval_Index : 5.18
#   Moyenne de Production budget $ : 38005882.35
#   Moyenne de Domestic gross $ : 43966586.24
#   Moyenne de Worldwide gross $ : 91143180.41
#
#
# Profession : sound_department
#   Moyenne de runtime_minutes : 104.60
#   Moyenne de movie_averageRating : 5.90
#   Moyenne de movie_numerOfVotes : 60157.80
#   Moyenne de approval_Index : 4.06
#   Moyenne de Production budget $ : 49142000.00
#   Moyenne de Domestic gross $ : 32202731.80
#   Moyenne de Worldwide gross $ : 99322619.10
#
#
# Profession : soundtrack
#   Moyenne de runtime_minutes : 109.09
#   Moyenne de movie_averageRating : 6.43
#   Moyenne de movie_numerOfVotes : 60838.54
#   Moyenne de approval_Index : 4.84
#   Moyenne de Production budget $ : 22872844.73
#   Moyenne de Domestic gross $ : 30511115.28
#   Moyenne de Worldwide gross $ : 47307097.06
#
#
# Profession : special_effects
#   Moyenne de runtime_minutes : 102.38
#   Moyenne de movie_averageRating : 6.00
#   Moyenne de movie_numerOfVotes : 85745.12
#   Moyenne de approval_Index : 4.61
#   Moyenne de Production budget $ : 19906250.00
#   Moyenne de Domestic gross $ : 31883951.00
#   Moyenne de Worldwide gross $ : 60483157.50
#
#
# Profession : stunts
#   Moyenne de runtime_minutes : 104.41
#   Moyenne de movie_averageRating : 5.71
#   Moyenne de movie_numerOfVotes : 106927.68
#   Moyenne de approval_Index : 4.39
#   Moyenne de Production budget $ : 41018181.82
#   Moyenne de Domestic gross $ : 50538547.00
#   Moyenne de Worldwide gross $ : 127499517.45
#
#
# Profession : transportation_department
#   Moyenne de runtime_minutes : 97.00
#   Moyenne de movie_averageRating : 5.70
#   Moyenne de movie_numerOfVotes : 5483.00
#   Moyenne de approval_Index : 3.48
#   Moyenne de Production budget $ : 500000.00
#   Moyenne de Domestic gross $ : 17000000.00
#   Moyenne de Worldwide gross $ : 17000000.00
#
#
# Profession : visual_effects
#   Moyenne de runtime_minutes : 103.15
#   Moyenne de movie_averageRating : 5.96
#   Moyenne de movie_numerOfVotes : 156172.49
#   Moyenne de approval_Index : 4.72
#   Moyenne de Production budget $ : 56323000.00
#   Moyenne de Domestic gross $ : 65083713.62
#   Moyenne de Worldwide gross $ : 157007233.80
#
#
# Profession : writer
#   Moyenne de runtime_minutes : 110.53
#   Moyenne de movie_averageRating : 6.45
#   Moyenne de movie_numerOfVotes : 138380.10
#   Moyenne de approval_Index : 5.08
#   Moyenne de Production budget $ : 36066768.41
#   Moyenne de Domestic gross $ : 48518826.40
#   Moyenne de Worldwide gross $ : 105564158.44
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_2616\2204673418.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['director_professions'] = df_clean['director_professions'].str.split(',')

# %% [markdown]
# ## ACP

# %% [markdown]
# ### Standardisation

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

df_standardized = df_clean.copy()

quantitative_cols = df_standardized.select_dtypes(include=['float64', 'int64']).columns.tolist()

# Initialiser le StandardScaler
scaler = StandardScaler()

# Appliquer la standardisation
df_standardized[quantitative_cols] = scaler.fit_transform(df_standardized[quantitative_cols])

df_standardized.describe()
# Out:
#        runtime_minutes  movie_averageRating  movie_numerOfVotes  \
# count     4.047000e+03         4.047000e+03        4.047000e+03
# mean     -3.511454e-16         7.584741e-16       -2.809163e-17
# std       1.000124e+00         1.000124e+00        1.000124e+00
# min      -2.260191e+00        -4.824648e+00       -6.317794e-01
# 25%      -7.187362e-01        -5.915417e-01       -5.311620e-01
# 50%      -1.717683e-01         9.756862e-02       -3.309243e-01
# 75%       4.746483e-01         6.882346e-01        1.002646e-01
# max       7.983026e+00         2.854010e+00        1.204416e+01
#
#        approval_Index  Production budget $  Domestic gross $  \
# count    4.047000e+03         4.047000e+03       4047.000000
# mean     1.966414e-16        -5.618327e-17          0.000000
# std      1.000124e+00         1.000124e+00          1.000124
# min     -3.360856e+00        -8.457744e-01         -0.705636
# 25%     -6.197273e-01        -6.224187e-01         -0.588257
# 50%     -2.821206e-03        -3.373315e-01         -0.320952
# 75%      6.567408e-01         2.754937e-01          0.163760
# max      3.649805e+00         9.479096e+00         10.770855
#
#        Worldwide gross $
# count       4.047000e+03
# mean        5.618327e-17
# std         1.000124e+00
# min        -5.785718e-01
# 25%        -5.099592e-01
# 50%        -3.507543e-01
# 75%         7.222142e-02
# max         1.509822e+01

# %% [markdown]
# ### Valeurs propres et projection dans le nouveau plan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 1. Matrice de corrélation
corr_matrix = df_standardized[quantitative_cols].corr()

# 2. Valeurs propres ET vecteurs propres
eigenvalues, eigenvectors = np.linalg.eig(corr_matrix)

print("Valeurs propres non triées :")
for i, val in enumerate(eigenvalues):
    print(f"Valeur propre {i + 1} : {val:.4f}")

# 3. Trier les vecteurs propres selon les valeurs propres décroissantes
idx_sorted = np.argsort(eigenvalues)[::-1]
eigenvalues_sorted = eigenvalues[idx_sorted]
eigenvectors_sorted = eigenvectors[:, idx_sorted]

print("\nDeux premières valeurs propres utilisées pour former le plan :")
print(f"PC1 : {eigenvalues_sorted[0]:.4f}")
print(f"PC2 : {eigenvalues_sorted[1]:.4f}")

print("\nVecteur propre PC1 :", eigenvectors_sorted[:, 0])
print("Vecteur propre PC2 :", eigenvectors_sorted[:, 1])

# 4. Garder les deux premiers vecteurs propres
PC1 = eigenvectors_sorted[:, 0]
PC2 = eigenvectors_sorted[:, 1]

# 5. Former la matrice de projection (2 premières composantes)
projection_matrix = np.column_stack((PC1, PC2))

# 6. Projeter les données (standardisées)
projected_data = df_standardized[quantitative_cols].values @ projection_matrix

# 7. Mettre en DataFrame pour visualisation
projected_df = pd.DataFrame(projected_data, columns=['PC1', 'PC2'])

# 8. Tracer le nuage de points
plt.figure(figsize=(10, 6))
plt.scatter(projected_df['PC1'], projected_df['PC2'], alpha=0.7)
plt.xlabel('Première composante principale (PC1)')
plt.ylabel('Deuxième composante principale (PC2)')
plt.title('Projection des individus sur le plan des deux premières composantes principales')
plt.grid(True)
plt.axhline(0, color='grey', lw=1)
plt.axvline(0, color='grey', lw=1)
plt.show()
# Out:
# Valeurs propres non triées :
# Valeur propre 1 : 3.7862
# Valeur propre 2 : 1.5697
# Valeur propre 3 : 0.7520
# Valeur propre 4 : 0.3832
# Valeur propre 5 : 0.3423
# Valeur propre 6 : 0.1133
# Valeur propre 7 : 0.0533
#
# Deux premières valeurs propres utilisées pour former le plan :
# PC1 : 3.7862
# PC2 : 1.5697
#
# Vecteur propre PC1 : [-0.27997886 -0.30514706 -0.41759283 -0.4014193  -0.34766892 -0.43073113
#  -0.43194085]
# Vecteur propre PC2 : [-0.24140743 -0.57220047 -0.09673021 -0.42014561  0.42363059  0.33350294
#   0.37113734]

# %% [markdown]
# ### Contributions (Paired with projections)

# %%
# Nombre d'individus
n = df_standardized.shape[0]

# Coordonnées des individus sur les composantes principales
Z = projected_data  # équivalent à projected_df[['PC1', 'PC2']].values

# Valeurs propres associées à PC1 et PC2
lambda1 = eigenvalues_sorted[0]
lambda2 = eigenvalues_sorted[1]

# Contribution des individus à PC1
contrib_PC1 = (Z[:, 0] ** 2) / (n * lambda1) * 100

# Contribution des individus à PC2
contrib_PC2 = (Z[:, 1] ** 2) / (n * lambda2) * 100

# Stocker dans un DataFrame
contributions_df = pd.DataFrame({
    'Contrib_PC1 (%)': contrib_PC1,
    'Contrib_PC2 (%)': contrib_PC2
})

# Affichage des contributions
print("\nContributions des individus aux composantes principales :")
print(contributions_df.head())

# Pairing contributions with projected data for visualization
projected_df['Contrib_PC1'] = contrib_PC1
projected_df['Contrib_PC2'] = contrib_PC2
plt.figure(figsize=(10, 6))
plt.scatter(projected_df['PC1'], projected_df['PC2'],
            c=projected_df['Contrib_PC1'], cmap='coolwarm', s=50)
plt.colorbar(label='Contribution à PC1 (%)')
plt.title("Projection colorée par la contribution des individus à PC1")
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.grid(True)
plt.show()
# Pairing contributions with projected data for visualization
projected_df['Contrib_PC1'] = contrib_PC1
projected_df['Contrib_PC2'] = contrib_PC2
plt.figure(figsize=(10, 6))
plt.scatter(projected_df['PC1'], projected_df['PC2'],
            c=projected_df['Contrib_PC2'], cmap='coolwarm', s=50)
plt.colorbar(label='Contribution à PC2 (%)')
plt.title("Projection colorée par la contribution des individus à PC2")
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.grid(True)
plt.show()
# Out:
# Contributions des individus aux composantes principales :
#    Contrib_PC1 (%)  Contrib_PC2 (%)
# 0         1.368471         1.206686
# 1         0.374526         0.395662
# 2         0.761793         0.514068
# 3         0.182073         0.267423
# 4         0.266848         0.192986

# %% [markdown]
# ### Correlation cercle

# %%
from matplotlib.patches import Circle

# 1. Récupérer les deux premières composantes (vecteurs propres)
PCs = eigenvectors_sorted[:, :2]  
correlation_circle_df = pd.DataFrame(
    PCs,
    index=quantitative_cols,  # noms des variables
    columns=['PC1', 'PC2']
)

# 3. Tracer le cercle des corrélations
plt.figure(figsize=(8, 8))
ax = plt.gca()

# Cercle unité
circle = Circle((0, 0), 1, facecolor='none', edgecolor='gray', linestyle='--')
ax.add_patch(circle)

# Axes
plt.axhline(0, color='gray', lw=1)
plt.axvline(0, color='gray', lw=1)

# Flèches pour chaque variable
for var in correlation_circle_df.index:
    x = correlation_circle_df.loc[var, 'PC1']
    y = correlation_circle_df.loc[var, 'PC2']
    plt.arrow(0, 0, x, y, head_width=0.03, head_length=0.03, fc='blue', ec='blue')
    plt.text(x * 1.1, y * 1.1, var, fontsize=9, ha='center', va='center')

# Style
plt.xlim(-1.1, 1.1)
plt.ylim(-1.1, 1.1)
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title("Cercle des corrélations")
plt.grid(True)
plt.gca().set_aspect('equal')
plt.show()
# Affichage des coordonnées des variables dans le nouveau plan (cercle des corrélations)
print("Coordonnées des variables dans le plan PC1-PC2 :\n")

for var in correlation_circle_df.index:
    x = correlation_circle_df.loc[var, 'PC1']
    y = correlation_circle_df.loc[var, 'PC2']
    print(f"{var} : PC1 = {round(x, 4)} ; PC2 = {round(y, 4)}")
# Out:
# Coordonnées des variables dans le plan PC1-PC2 :
#
# runtime_minutes : PC1 = -0.28 ; PC2 = -0.2414
# movie_averageRating : PC1 = -0.3051 ; PC2 = -0.5722
# movie_numerOfVotes : PC1 = -0.4176 ; PC2 = -0.0967
# approval_Index : PC1 = -0.4014 ; PC2 = -0.4201
# Production budget $ : PC1 = -0.3477 ; PC2 = 0.4236
# Domestic gross $ : PC1 = -0.4307 ; PC2 = 0.3335
# Worldwide gross $ : PC1 = -0.4319 ; PC2 = 0.3711

# %% [markdown]
# ## ACM ON genres

# %%
import pandas as pd
import matplotlib.pyplot as plt
import prince  # pip install prince

# 1. Copie de sécurité
df = df_clean.copy()

# 2. Nettoyage et séparation des genres multiples
df['genres'] = df['genres'].fillna('').apply(lambda x: [genre.strip() for genre in x.split(',') if genre.strip()])

# 3. Création du tableau disjonctif pour genres
genres_dummies = df['genres'].explode().reset_index().dropna()
genres_dummies['val'] = 1
genres_wide = genres_dummies.pivot_table(index='index', columns='genres', values='val', fill_value=0)
genres_wide.index = df.index  # pour garder le même index que df


# 4. Appliquer l’ACM
mca = prince.MCA(n_components=2, random_state=42)
mca = mca.fit(genres_wide)

# 5. Projeter les individus
mca_ind = mca.transform(genres_wide)

# 6. Inertie (variance expliquée par axe)
try:
    # Vieilles versions de prince
    inertie = mca.explained_inertia_
except AttributeError:
    # Nouvelles versions de prince
    eigenvalues = mca.eigenvalues_
    inertie = eigenvalues / eigenvalues.sum()

if inertie is not None:
    print("Inertie expliquée par axe :")
    for i, inertia in enumerate(inertie[:2]):  # seulement pour les deux premiers axes
        print(f"Axe {i+1} : {round(inertia * 100, 2)} %")
else:
    print("Inertie non disponible.")

# 7. Coordonnées des individus (sur les deux premiers axes)
mca_ind.columns = ["Axe 1", "Axe 2"]  # pour un affichage plus clair
print("\nCoordonnées des individus :")
print(mca_ind.head())

# 8. Visualisation des individus
plt.figure(figsize=(8, 6))
plt.scatter(mca_ind["Axe 1"], mca_ind["Axe 2"], alpha=0.5)
plt.title("Projection des individus selon les genres (ACM)")
plt.xlabel(f"Axe 1 ({round(inertie[0]*100, 2)}%)")
plt.ylabel(f"Axe 2 ({round(inertie[1]*100, 2)}%)")
plt.grid(True)
plt.show()
# Out:
# Inertie expliquée par axe :
# Axe 1 : 53.68 %
# Axe 2 : 46.32 %
#
# Coordonnées des individus :
#       Axe 1     Axe 2
# 0  0.513799  0.235779
# 2  0.513799  0.235779
# 3  0.618106  0.092797
# 5  0.513799  0.235779
# 6  0.511582 -0.086953

# %% [markdown]
# # cah

# %%
# Ne garder que les colonnes numériques
df_num = df_clean.select_dtypes(include=['float64', 'int64'])

# 1. Standardiser les données
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df_num)

# 2. Effectuer la liaison hiérarchique (methode Ward)
Z = linkage(df_scaled, method='ward', metric='euclidean')

# 3. Tracer le dendrogramme
plt.figure(figsize=(12, 6))
dendrogram(Z, truncate_mode='level', p=30)
plt.title("Dendrogramme de la CAH")
plt.xlabel("Observations")
plt.ylabel("Distance")
plt.axhline(y=15, color='r', linestyle='--')
plt.show()

# 4. Définir les clusters
n_clusters = 3
labels_cah = fcluster(Z, n_clusters, criterion='maxclust')

# 5. Ajouter au DataFrame initial
df_clean['Cluster_CAH'] = labels_cah

# 6. Visualiser sur le plan PC1-PC2
plt.figure(figsize=(10, 8))
sns.scatterplot(x=df_scaled[:, 0], y=df_scaled[:, 1], hue=labels_cah, palette='Set1')
plt.title('Projection des individus colorés par cluster CAH')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.legend(title='Cluster CAH')
plt.show()

# Seulement sur les variables numériques
caracterisation = df_clean.select_dtypes(include=['float64', 'int64']).groupby(df_clean['Cluster_CAH']).mean()

print("Caractérisation des classes CAH :")
print(caracterisation)
# Out:
# Caractérisation des classes CAH :
#              runtime_minutes  movie_averageRating  movie_numerOfVotes  \
# Cluster_CAH
# 1                 122.072569             6.964151       420576.885341
# 2                  98.581061             5.464242        25869.128788
# 3                 114.216879             6.817125       107885.548086
#
#              approval_Index  Production budget $  Domestic gross $  \
# Cluster_CAH
# 1                  6.364475         1.033555e+08      1.561986e+08
# 2                  3.628277         2.193078e+07      1.715594e+07
# 3                  5.482732         2.577139e+07      3.548168e+07
#
#              Worldwide gross $
# Cluster_CAH
# 1                 3.894287e+08
# 2                 2.797504e+07
# 3                 6.449555e+07

# %% [markdown]
# # K-means

# %% [markdown]
# ## Elbow method

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# 1. Copy of your data
df = df_clean.copy()

# 2. Keep only numeric columns
df_numeric = df.select_dtypes(include=['number'])

# 3. Compute distortions (inertia) for different values of k
inertias = []
k_values = range(1, 11)  # We'll test k = 1 to 10

for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(df_numeric)
    inertias.append(kmeans.inertia_)  # Inertia = within-cluster sum of squares

# 4. Plot the Elbow curve
plt.figure(figsize=(8, 5))
plt.plot(k_values, inertias, marker='o')
plt.title('Méthode du coude pour déterminer le nombre optimal de clusters')
plt.xlabel('Nombre de clusters (k)')
plt.ylabel('Inertie (distorsion)')
plt.grid(True)
plt.show()
# Out:
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\subprocess.py", line 1538, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^

# %% [markdown]
# ### k-means with 3 clusters

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# ======= 1. Chargement des données =======
# Suppose ton DataFrame s'appelle df_clean
# On ne garde que les colonnes numériques
df_numerique = df_clean.select_dtypes(include=['float64', 'int64'])

# Standardisation des données (très important pour PCA et KMeans)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df_numerique)

# ======= 2. Réduction de dimension avec PCA =======
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# ======= 3. Clustering avec KMeans =======
kmeans = KMeans(n_clusters=3, random_state=42)
clusters = kmeans.fit_predict(X_scaled)

# ======= 4. Préparation des données pour le graphique =======
pca_df = pd.DataFrame({
    'Composante Principale 1': X_pca[:, 0],
    'Composante Principale 2': X_pca[:, 1],
    'Cluster': clusters
})

# ======= 5. Visualisation =======
plt.figure(figsize=(12, 8))
sns.scatterplot(
    data=pca_df,
    x='Composante Principale 1',
    y='Composante Principale 2',
    hue='Cluster',
    palette='viridis',
    s=50,
    edgecolor='white',
    linewidth=0.5
)

plt.title('Visualisation des films par clusters (K-Means avec k=3)', fontsize=16)
plt.xlabel('Composante Principale 1', fontsize=14)
plt.ylabel('Composante Principale 2', fontsize=14)
plt.legend(title='Cluster', title_fontsize=13, fontsize=11)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Associer les clusters au DataFrame
df_analyse = df_clean.copy()
df_analyse['Cluster'] = clusters

# 2. Garder uniquement les colonnes numériques
df_numeric = df_analyse.select_dtypes(include=['int64', 'float64'])

# 3. Voir la taille de chaque cluster
print("Nombre d'observations par cluster :")
print(df_analyse['Cluster'].value_counts())
print("\n")

# 4. Statistiques descriptives par cluster (moyennes)
cluster_description = df_numeric.groupby(df_analyse['Cluster']).mean()
print("Moyennes des variables par cluster :")
print(cluster_description)
print("\n")

# 5. Médianes par cluster
cluster_median = df_numeric.groupby(df_analyse['Cluster']).median()
print("Médianes des variables par cluster :")
print(cluster_median)
print("\n")

# 6. Visualiser la distribution des variables importantes par cluster
variables_to_plot = ['Production budget $', 'Worldwide gross $', 'Domestic gross',
                     'runtime_minutes', 'movie_averageRating', 'movie_numberOfVotes', 'approval_Index']

for var in variables_to_plot:
    if var in df_analyse.columns:
        plt.figure(figsize=(10, 6))
        sns.boxplot(x='Cluster', y=var, data=df_analyse, palette='viridis')
        plt.title(f'Distribution de {var} selon les clusters', fontsize=14)
        plt.xlabel('Cluster', fontsize=12)
        plt.ylabel(var, fontsize=12)
        plt.grid(True)
        plt.show()
# Out:
# Nombre d'observations par cluster :
# Cluster
# 0    1926
# 2    1856
# 1     265
# Name: count, dtype: int64
#
#
# Moyennes des variables par cluster :
#          runtime_minutes  movie_averageRating  movie_numerOfVotes  \
# Cluster
# 0              99.661994             5.682399        37800.049844
# 1             130.037736             7.216981       618451.449057
# 2             118.857759             7.029957       165464.946659
#
#          approval_Index  Production budget $  Domestic gross $  \
# Cluster
# 0              3.966436         2.465271e+07      2.359156e+07
# 1              6.832506         1.438166e+08      2.385908e+08
# 2              5.871922         3.614770e+07      5.060043e+07
#
#          Worldwide gross $
# Cluster
# 0             4.241159e+07
# 1             6.346480e+08
# 2             1.006567e+08
#
#
# Médianes des variables par cluster :
#          runtime_minutes  movie_averageRating  movie_numerOfVotes  \
# Cluster
# 0                   98.0                  5.8             24545.5
# 1                  128.0                  7.2            492242.0
# 2                  117.0                  7.0            121422.0
#
#          approval_Index  Production budget $  Domestic gross $  \
# Cluster
# 0              4.135079           17000000.0        14998048.5
# 1              6.783635          150000000.0       205343774.0
# 2              5.769884           26000000.0        38879813.0
#
#          Worldwide gross $
# Cluster
# 0               20084318.0
# 1              535663443.0
# 2               66764655.5
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_2616\2335559299.py:36: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Cluster', y=var, data=df_analyse, palette='viridis')
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_2616\2335559299.py:36: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Cluster', y=var, data=df_analyse, palette='viridis')
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_2616\2335559299.py:36: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Cluster', y=var, data=df_analyse, palette='viridis')
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_2616\2335559299.py:36: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Cluster', y=var, data=df_analyse, palette='viridis')
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_2616\2335559299.py:36: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Cluster', y=var, data=df_analyse, palette='viridis')

# %% [markdown]
# # différences significatives

# %%
# 7. Calcul de la moyenne générale pour chaque variable
global_means = df_numeric.mean()

# 8. Pour chaque cluster, calculer la différence absolue entre ses moyennes et la moyenne globale
diffs = pd.DataFrame()

for cluster in cluster_description.index:
    diff = (cluster_description.loc[cluster] - global_means).abs()
    diff.name = f"Cluster {cluster}"
    diffs = pd.concat([diffs, diff], axis=1)

print("\n Différences absolues entre chaque cluster et la moyenne générale :")
print(diffs)

# 9. Trouver les variables les plus discriminantes pour chaque cluster
print("\n Variables les plus discriminantes pour chaque cluster :")
for cluster in cluster_description.index:
    relevant_diff = diffs[f"Cluster {cluster}"]
    top_variable = relevant_diff.idxmax()
    top_value = relevant_diff.max()

    print(f"\n🔵 Cluster {cluster} :")
    print(f"Variable la plus discriminante : {top_variable} (Différence absolue : {round(top_value, 2)})")
# Out:
#  Différences absolues entre chaque cluster et la moyenne générale :
#                         Cluster 0     Cluster 1     Cluster 2
# runtime_minutes      1.079242e+01  1.958333e+01  8.403348e+00
# movie_averageRating  7.184908e-01  8.160916e-01  6.290673e-01
# movie_numerOfVotes   9.656997e+04  4.840814e+05  3.109493e+04
# approval_Index       1.061549e+00  1.804520e+00  8.439366e-01
# Production budget $  1.307466e+07  1.060892e+08  1.579667e+06
# Domestic gross $     2.646485e+07  1.885344e+08  5.440104e+05
# Worldwide gross $    6.549189e+07  5.267445e+08  7.246729e+06
#
#  Variables les plus discriminantes pour chaque cluster :
#
# 🔵 Cluster 0 :
# Variable la plus discriminante : Worldwide gross $ (Différence absolue : 65491886.42)
#
# 🔵 Cluster 1 :
# Variable la plus discriminante : Worldwide gross $ (Différence absolue : 526744537.84)
#
# 🔵 Cluster 2 :
# Variable la plus discriminante : Worldwide gross $ (Différence absolue : 7246729.14)
